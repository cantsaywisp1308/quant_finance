# %%
import re

pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Obtaining dependency information for pdfminer.six from https://files.pythonhosted.org/packages/64/29/d1d9f6b900191288b77613ddefb73ed35b48fb35e44aaf8b01b0422b759d/pdfminer_six-20251107-py3-none-any.whl.metadata
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from pdfminer.six) (3.4.4)
# Collecting cryptography>=36.0.0 (from pdfminer.six)
#   Obtaining dependency information for cryptography>=36.0.0 from https://files.pythonhosted.org/packages/7e/bf/80fbf45253ea585a1e492a6a17efcb93467701fa79e71550a430c5e60df0/cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=2.0.0 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (2.0.0)
# Requirement already satisfied: pycparser in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six) (2.23)
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB 435.7 kB/s eta 0:00:13
#     --------------------------------------- 0.1/5.6 MB 1.2 MB/s eta 0:00:05
#    --- ------------------------------------ 0.5/5.6 MB 3.2 MB/s eta 0:00:02
#    ------- -------------------------------- 1.1/5.6 MB 5.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.6 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------  5.6/5.6 MB 19.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 18.9 MB/s eta 0:00:00
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.5 MB 68.9 MB/s eta 0:00:01
#    --------------- ------------------------ 1.4/3.5 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.5 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 22.5 MB/s eta 0:00:00
# Installing collected packages: cryptography, pdfminer.six
# Successfully installed cryptography-46.0.3 pdfminer.six-20251107
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdfminer.high_level import extract_pages, extract_text

# %%
for page_layout in extract_pages("sample.pdf"):
    for element in page_layout:
        print(element)
# Out:
# <LTTextBoxHorizontal(0) 72.000,690.395,408.206,715.941 'My PDFMiner trial\nThere are 5 names in the list: Julia, Kerian, Paul, Marko and Spencer\n'>
# <LTTextBoxHorizontal(1) 77.000,655.299,106.337,666.299 'Name\n'>
# <LTTextBoxHorizontal(2) 77.000,631.651,99.616,642.651 'Julia\n'>
# <LTTextBoxHorizontal(3) 77.000,608.002,108.790,619.002 'Kerian\n'>
# <LTTextBoxHorizontal(4) 77.000,584.353,99.011,595.353 'Paul\n'>
# <LTTextBoxHorizontal(5) 77.000,560.704,107.558,571.704 'Marko\n'>
# <LTTextBoxHorizontal(6) 77.000,537.055,117.964,548.055 'Spencer\n'>
# <LTTextBoxHorizontal(7) 233.000,655.299,260.500,666.299 'Major\n'>
# <LTTextBoxHorizontal(8) 233.000,631.651,323.462,642.651 'Computer Science\n'>
# <LTTextBoxHorizontal(9) 233.000,608.002,286.790,619.002 'Economics\n'>
# <LTTextBoxHorizontal(10) 233.000,584.353,272.116,595.353 'Finance\n'>
# <LTTextBoxHorizontal(11) 233.000,560.704,291.696,571.704 'Engineering\n'>
# <LTTextBoxHorizontal(12) 233.000,537.055,257.442,548.055 'Math\n'>
# <LTTextBoxHorizontal(13) 389.000,655.299,420.174,666.299 'Salary\n'>
# <LTTextBoxHorizontal(14) 389.000,631.651,419.580,642.651 '85000\n'>
# <LTTextBoxHorizontal(15) 389.000,608.002,419.580,619.002 '80000\n'>
# <LTTextBoxHorizontal(16) 389.000,584.353,419.580,595.353 '90000\n'>
# <LTTextBoxHorizontal(17) 389.000,560.704,419.580,571.704 '95000\n'>
# <LTTextBoxHorizontal(18) 389.000,537.055,419.580,548.055 '84000\n'>
# <LTLine 384.000,652.709,384.000,676.358>
# <LTLine 540.000,652.709,540.000,676.358>
# <LTLine 384.500,676.358,539.500,676.358>
# <LTLine 228.000,652.709,228.000,676.358>
# <LTLine 228.500,676.358,383.500,676.358>
# <LTLine 72.000,652.709,72.000,676.358>
# <LTLine 72.500,676.358,227.500,676.358>
# <LTLine 384.000,629.061,384.000,652.709>
# <LTLine 540.000,629.061,540.000,652.709>
# <LTLine 384.500,652.709,539.500,652.709>
# <LTLine 228.000,629.061,228.000,652.709>
# <LTLine 228.500,652.709,383.500,652.709>
# <LTLine 72.000,629.061,72.000,652.709>
# <LTLine 72.500,652.709,227.500,652.709>
# <LTLine 384.000,605.412,384.000,629.061>
# <LTLine 540.000,605.412,540.000,629.061>
# <LTLine 384.500,629.061,539.500,629.061>
# <LTLine 228.000,605.412,228.000,629.061>
# <LTLine 228.500,629.061,383.500,629.061>
# <LTLine 72.000,605.412,72.000,629.061>
# <LTLine 72.500,629.061,227.500,629.061>
# <LTLine 384.000,581.763,384.000,605.412>
# <LTLine 540.000,581.763,540.000,605.412>
# <LTLine 384.500,605.412,539.500,605.412>
# <LTLine 228.000,581.763,228.000,605.412>
# <LTLine 228.500,605.412,383.500,605.412>
# <LTLine 72.000,581.763,72.000,605.412>
# <LTLine 72.500,605.412,227.500,605.412>
# <LTLine 384.000,558.114,384.000,581.763>
# <LTLine 540.000,558.114,540.000,581.763>
# <LTLine 384.500,581.763,539.500,581.763>
# <LTLine 228.000,558.114,228.000,581.763>
# <LTLine 228.500,581.763,383.500,581.763>
# <LTLine 72.000,558.114,72.000,581.763>
# <LTLine 72.500,581.763,227.500,581.763>
# <LTLine 384.000,534.465,384.000,558.114>
# <LTLine 540.000,534.465,540.000,558.114>
# <LTLine 384.500,558.114,539.500,558.114>
# <LTLine 383.500,534.465,540.500,534.465>
# <LTLine 228.000,534.465,228.000,558.114>
# <LTLine 228.500,558.114,383.500,558.114>
# <LTLine 227.500,534.465,384.500,534.465>
# <LTLine 72.000,534.465,72.000,558.114>
# <LTLine 72.500,558.114,227.500,558.114>
# <LTLine 71.500,534.465,228.500,534.465>

# %%
text = extract_text("sample.pdf")
print(text)
# Out:
# My PDFMiner trial
# There are 5 names in the list: Julia, Kerian, Paul, Marko and Spencer
#
# Name
#
# Julia
#
# Kerian
#
# Paul
#
# Marko
#
# Spencer
#
# Major
#
# Computer Science
#
# Economics
#
# Finance
#
# Engineering
#
# Math
#
# Salary
#
# 85000
#
# 80000
#
# 90000
#
# 95000
#
# 84000

# %%
import re
pattern = re.compile(r"[a-zA-Z]+,{1}\s{1}")
matches = pattern.findall(text)
print(matches)
# Out:
# ['Julia, ', 'Kerian, ', 'Paul, ']

# %%
pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Obtaining dependency information for PyMuPDF from https://files.pythonhosted.org/packages/dd/c3/d0047678146c294469c33bae167c8ace337deafb736b0bf97b9bc481aa65/pymupdf-1.26.7-cp310-abi3-win_amd64.whl.metadata
#   Downloading pymupdf-1.26.7-cp310-abi3-win_amd64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.7-cp310-abi3-win_amd64.whl (18.4 MB)
#    ---------------------------------------- 0.0/18.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.4 MB 435.7 kB/s eta 0:00:43
#    ---------------------------------------- 0.1/18.4 MB 744.7 kB/s eta 0:00:25
#     --------------------------------------- 0.4/18.4 MB 2.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.1/18.4 MB 10.1 MB/s eta 0:00:02
#    --------------- ------------------------ 7.0/18.4 MB 27.8 MB/s eta 0:00:01
#    --------------------------- ------------ 12.6/18.4 MB 108.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.4/18.4 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  18.4/18.4 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 18.4/18.4 MB 59.4 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (11.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz
import PIL.Image
import io

pdf = fitz.open("sample.pdf")
counter = 1
for i in range(len(pdf)):
    page = pdf[i]
    images = page.get_images()
    for image in images:
        base_img = pdf.extract_image(image[0])
        image_data = base_img["image"]
        img = PIL.Image.open(io.BytesIO(image_data))
        extension = base_img["ext"]
        img.save(open(f"image{counter}.{extension}", "wb"))
        counter += 1

# %%
pip install tabula-py
# Out:
# Collecting tabula-py
#   Obtaining dependency information for tabula-py from https://files.pythonhosted.org/packages/2f/80/10bc6f303054d1a06eb8628f90e5997f4b1272956a477230f3fa95637c28/tabula_py-2.10.0-py3-none-any.whl.metadata
#   Downloading tabula_py-2.10.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pandas>=0.25.3 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from tabula-py) (2.3.3)
# Requirement already satisfied: numpy>1.24.4 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from tabula-py) (2.3.3)
# Collecting distro (from tabula-py)
#   Obtaining dependency information for distro from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from pandas>=0.25.3->tabula-py) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from pandas>=0.25.3->tabula-py) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\coding_places\python\cafa6_ontology_llm\venv_gpu\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.17.0)
# Downloading tabula_py-2.10.0-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.0 MB 1.3 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/12.0 MB 3.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/12.0 MB 15.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.9/12.0 MB 33.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.3/12.0 MB 46.9 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 54.7 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.9.0 tabula-py-2.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula

tables = tabula.read_pdf("sample.pdf", pages="all")
df = tables[0]
print(df)
# Out:
#       Name             Major  Salary
# 0    Julia  Computer Science   85000
# 1   Kerian         Economics   80000
# 2     Paul           Finance   90000
# 3    Marko       Engineering   95000
# 4  Spencer              Math   84000
